# %%
# !python -V
# Out:
# Python 3.7.16

# %%
# !sudo apt-get update
# !sudo apt-get install espeak-ng
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [66.7 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,311 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,663 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,606 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,748 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [45.2 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,606 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,230 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,653 kB]
# Get:17 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,911 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,526 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:21 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:22 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:23 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [33.6 kB]
# Get:24 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [57.8 kB]
# Fetched 28.9 MB in 2s (11.8 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 124 not upgraded.
# Need to get 1,382 kB of archives.
# After this operation, 3,178 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudio2 amd64 19.6.0-1.1 [65.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsonic0 amd64 0.2.0-11build1 [10.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak-data amd64 1.48.15+dfsg-3 [1,085 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak1 amd64 1.48.15+dfsg-3 [156 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak amd64 1.48.15+dfsg-3 [64.2 kB]
# Fetched 1,382 kB in 1s (2,105 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 5.)
# debconf: falling back to frontend: Readline
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 127400 files and directories currently installed.)
# Preparing to unpack .../libportaudio2_19.6.0-1.1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1.1) ...
# Selecting previously unselected package libsonic0:amd64.
# Preparing to unpack .../libsonic0_0.2.0-11build1_amd64.deb ...
# Unpacking libsonic0:amd64 (0.2.0-11build1) ...
# Selecting previously unselected package espeak-data:amd64.
# Preparing to unpack .../espeak-data_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak-data:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package libespeak1:amd64.
# Preparing to unpack .../libespeak1_1.48.15+dfsg-3_amd64.deb ...
# Unpacking libespeak1:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package espeak.
# Preparing to unpack .../espeak_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak (1.48.15+dfsg-3) ...
# Setting up libportaudio2:amd64 (19.6.0-1.1) ...
# Setting up libsonic0:amd64 (0.2.0-11build1) ...
# Setting up espeak-data:amd64 (1.48.15+dfsg-3) ...
# Setting up libespeak1:amd64 (1.48.15+dfsg-3) ...
# Setting up espeak (1.48.15+dfsg-3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link

# %%
# %pip install -r /home/hoang/EmpathyEar/StyleTTS2/requirements.txt
# Out:
# Collecting git+https://github.com/resemble-ai/monotonic_align.git (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 17))
#   Cloning https://github.com/resemble-ai/monotonic_align.git to /tmp/pip-req-build-3zvpcgcs
#   Running command git clone --filter=blob:none --quiet https://github.com/resemble-ai/monotonic_align.git /tmp/pip-req-build-3zvpcgcs
#   Resolved https://github.com/resemble-ai/monotonic_align.git to commit 78b985be210a03d08bc3acc01c4df0442105366f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: SoundFile in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: torchaudio in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 2)) (0.13.1)
# Requirement already satisfied: munch in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: torch in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 4)) (1.13.1)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: pyyaml in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: librosa in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (0.10.2.post1)
# Requirement already satisfied: nltk in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: matplotlib in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (3.5.3)
# Requirement already satisfied: accelerate in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 10)) (0.20.3)
# Requirement already satisfied: transformers in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (4.30.2)
# Requirement already satisfied: einops in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: einops-exts in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 13)) (0.0.4)
# Requirement already satisfied: tqdm in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 14)) (4.65.0)
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions in /usr/local/envs/empathyear/lib/python3.7/site-packages (from -r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 16)) (4.7.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from SoundFile->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 1)) (1.15.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from torch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 4)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from torch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 4)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from torch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 4)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from torch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 4)) (11.7.99)
# Requirement already satisfied: wheel in /usr/local/envs/empathyear/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 4)) (0.38.4)
# Requirement already satisfied: setuptools in /usr/local/envs/empathyear/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 4)) (65.6.3)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from munch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 3)) (4.13.0)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (1.7.3)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (0.4)
# Requirement already satisfied: pooch>=1.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (0.24.2)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (1.21.5)
# Requirement already satisfied: joblib>=0.14 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (0.56.4)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (0.3.7)
# Requirement already satisfied: click in /usr/local/envs/empathyear/lib/python3.7/site-packages (from nltk->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from nltk->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 8)) (2024.4.16)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: psutil in /usr/local/envs/empathyear/lib/python3.7/site-packages (from accelerate->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 10)) (5.9.8)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (0.16.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/envs/empathyear/lib/python3.7/site-packages (from transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (3.12.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (0.13.3)
# Requirement already satisfied: requests in /usr/local/envs/empathyear/lib/python3.7/site-packages (from transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (2.28.1)
# Requirement already satisfied: pycparser in /usr/local/envs/empathyear/lib/python3.7/site-packages (from cffi>=1.0->SoundFile->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 1)) (2.21)
# Requirement already satisfied: fsspec in /usr/local/envs/empathyear/lib/python3.7/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (2022.11.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from importlib-metadata>=1.7.0->munch->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 3)) (3.15.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from numba>=0.51.0->librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (0.39.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from pooch>=1.1->librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from requests->transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (2024.8.30)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from requests->transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from requests->transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from requests->transformers->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 11)) (1.26.14)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/envs/empathyear/lib/python3.7/site-packages (from scikit-learn>=0.20.0->librosa->-r /kaggle/working/EmpathyEar/StyleTTS2/requirements.txt (line 7)) (2.2.0)
# Building wheels for collected packages: typing, monotonic-align
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26304 sha256=b2b7495aa39635e44d36a5968258ac2d43d33338cd8dc5a4d8cfa27248124ce5
#   Stored in directory: /root/.cache/pip/wheels/f9/53/6b/89c460c5ace18b7d98e8b73531a93e647e5cec1d7eaa794853
#   Building wheel for monotonic-align (pyproject.toml) ... done
#   Created wheel for monotonic-align: filename=monotonic_align-1.2-cp37-cp37m-linux_x86_64.whl size=1666331 sha256=e1ae017ce3df51fc50e665e0a877d6882c5b4a015297c39ede7f89eabe8fe8d2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-heru2pdk/wheels/3c/77/69/d8469156d486dd51c784b1b149ecb2a86f23cb139359a4a375
# Successfully built typing monotonic-align
# Installing collected packages: pydub, typing, monotonic-align
# Successfully installed monotonic-align-1.2 pydub-0.25.1 typing-3.7.4.3

# %%
import json

data = [
    {
        "User Query": "I've been planning this trip for months! I can't wait to explore the city and try all the local food.",
        "Conversation History": "[User]Are you excited about your upcoming trip? [Agent]Absolutely! Traveling to new places is always a great experience.",
        "Event Scenario": "Excitement about travel.",
        "Rationale": "The user is eagerly anticipating an upcoming trip and looking forward to new experiences.",
        "Goal to Response": "Encouraging excitement and sharing in the anticipation of discovery.",
        "Agent Gender": "Male",
        "Agent Age": "Middle-aged",
        "Agent Timbre and Tone": "Warm",
        "Empathetic Response": "That sounds amazing! Exploring a new city and trying local food is one of the best parts of traveling. I’m sure you’ll make wonderful memories on this trip!",
        "Emotional Response": "Excited"
    },
    {
        "User Query": "I feel so overwhelmed with all these exams coming up. I don't know how I'll manage to get through them.",
        "Conversation History": "[User]I have so many exams next week... [Agent]Exams can be stressful, but I’m sure you’ll do great!",
        "Event Scenario": "Academic stress and anxiety.",
        "Rationale": "The user is feeling overwhelmed and anxious about upcoming exams.",
        "Goal to Response": "Providing reassurance and practical advice to ease stress.",
        "Agent Gender": "Female",
        "Agent Age": "Young adults",
        "Agent Timbre and Tone": "Soft",
        "Empathetic Response": "I completely understand how stressful exams can be. Just take it one step at a time, and don’t forget to give yourself breaks. You’ve got this, and all your hard work will pay off!",
        "Emotional Response": "Supportive"
    },
    {
        "User Query": "I just started learning the guitar, but it's so difficult! My fingers hurt, and I feel like I'm not improving at all.",
        "Conversation History": "[User]I started playing guitar last week. [Agent]That’s great! Learning a new instrument is such a rewarding experience.",
        "Event Scenario": "Struggles with learning a new skill.",
        "Rationale": "The user is facing challenges in learning a new instrument and needs motivation.",
        "Goal to Response": "Encouraging perseverance and highlighting progress.",
        "Agent Gender": "Male",
        "Agent Age": "Young adults",
        "Agent Timbre and Tone": "Melodious",
        "Empathetic Response": "Learning the guitar can be tough at first, but don’t give up! The sore fingers mean you’re making progress. With practice, it’ll get easier, and soon you’ll be playing your favorite songs!",
        "Emotional Response": "Motivational"
    }
]
with open("/kaggle/working/EmpathyEar/Data/Test_tts/test_data.json", "w", encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

# %%
# !python /home/hoang/EmpathyEar/inference_StyleTTS2.py
# Out:
# Folder 'TTS_results/ED_test/test1' already exists.
# Folder 'TTS_results/ED_test/test2' created.
# 177
# bert loaded
# bert_encoder loaded
# predictor loaded
# decoder loaded
# text_encoder loaded
# predictor_encoder loaded
# style_encoder loaded
# diffusion loaded
# text_aligner loaded
# pitch_extractor loaded
# mpd loaded
# msd loaded
# wd loaded
# RTF = 0.178463
# Saved as TTS_results/ED_test/test2/soft.wav
# Folder 'TTS_results/ED_test/test3' created.
# 177
# bert loaded
# bert_encoder loaded
# predictor loaded
# decoder loaded
# text_encoder loaded
# predictor_encoder loaded
# style_encoder loaded
# diffusion loaded
# text_aligner loaded
# pitch_extractor loaded
# mpd loaded
# msd loaded
# wd loaded
# RTF = 0.050216
# Saved as TTS_results/ED_test/test3/melodious.wav
# /usr/local/envs/empathyear/lib/python3.7/site-packages/torch/nn/modules/rnn.py:70: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# /usr/local/envs/empathyear/lib/python3.7/site-packages/torch/nn/modules/rnn.py:70: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
from IPython.display import Audio

# Phát file WAV
Audio("/home/hoang/EmpathyEar/TTS_results/ED_test/test1/warm.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Phát file WAV
Audio("/home/hoang/EmpathyEar/TTS_results/ED_test/test2/soft.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Phát file WAV
Audio("/home/hoang/EmpathyEar/TTS_results/ED_test/test3/melodious.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
