# %%
# !python -V
# Out:
# Python 3.8.20

# %%
import torch
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 12.1
# True

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs -o rustup.sh
# !sh rustup.sh -y
# Out:
# info: downloading installer
#
# Welcome to Rust!
#
# This will download and install the official compiler for the Rust
# programming language, and its package manager, Cargo.
#
# Rustup metadata and toolchains will be installed into the Rustup
# home directory, located at:
#
#   /home/hoang/.rustup
#
# This can be modified with the RUSTUP_HOME environment variable.
#
# The Cargo home directory is located at:
#
#   /home/hoang/.cargo
#
# This can be modified with the CARGO_HOME environment variable.
#
# The cargo, rustc, rustup and other commands will be added to
# Cargo's bin directory, located at:
#
#   /home/hoang/.cargo/bin
#
# This path will then be added to your PATH environment variable by
# modifying the profile files located at:
#
#   /home/hoang/.profile
#   /home/hoang/.bash_profile
#   /home/hoang/.bashrc
#
# You can uninstall at any time with rustup self uninstall and
# these changes will be reverted.
#
# Current installation options:
#
#
#    default host triple: x86_64-unknown-linux-gnu
#      default toolchain: stable (default)
#                profile: default
#   modify PATH variable: yes
#
# 1) Proceed with standard installation (default - just press enter)
# 2) Customize installation
# 3) Cancel installation
# >^C

# %%
# !source "$HOME/.cargo/env"

# %%
# %cd /home/hoang/EmpathyEar/chatglm
# !export PATH="$HOME/.cargo/bin:$PATH" && pip install -r requirements.txt
# Out:
# /home/hoang/EmpathyEar/chatglm
# Collecting protobuf>=4.25.3 (from -r requirements.txt (line 3))
#   Using cached protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting transformers>=4.39.3 (from -r requirements.txt (line 4))
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Collecting tokenizers>=0.15.0 (from -r requirements.txt (line 5))
#   Using cached tokenizers-0.21.0.tar.gz (343 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cpm_kernels>=1.0.11 (from -r requirements.txt (line 6))
#   Downloading cpm_kernels-1.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting torch>=2.1.0 (from -r requirements.txt (line 7))
#   Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting gradio>=4.26.0 (from -r requirements.txt (line 8))
#   Downloading gradio-4.44.1-py3-none-any.whl.metadata (15 kB)
# Collecting sentencepiece>=0.2.0 (from -r requirements.txt (line 9))
#   Downloading sentencepiece-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting sentence_transformers>=2.4.0 (from -r requirements.txt (line 10))
#   Downloading sentence_transformers-3.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting accelerate>=0.29.2 (from -r requirements.txt (line 11))
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Collecting streamlit>=1.33.0 (from -r requirements.txt (line 12))
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting fastapi>=0.110.0 (from -r requirements.txt (line 13))
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting loguru~=0.7.2 (from -r requirements.txt (line 14))
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting mdtex2html==1.3.0 (from -r requirements.txt (line 15))
#   Downloading mdtex2html-1.3.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting latex2mathml==3.75.0 (from -r requirements.txt (line 16))
#   Downloading latex2mathml-3.75.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jupyter_client>=8.6.1 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (8.6.3)
# Collecting markdown (from mdtex2html==1.3.0->-r requirements.txt (line 15))
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting filelock (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Downloading huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# Collecting numpy>=1.17 (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging>=20.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from transformers>=4.39.3->-r requirements.txt (line 4)) (24.2)
# Collecting pyyaml>=5.1 (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Downloading regex-2024.11.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers>=0.15.0 (from -r requirements.txt (line 5))
#   Downloading tokenizers-0.20.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Downloading safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers>=4.39.3->-r requirements.txt (line 4))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch>=2.1.0->-r requirements.txt (line 7)) (4.12.2)
# Collecting sympy (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->-r requirements.txt (line 7))
#   Downloading nvidia_nvjitlink_cu12-12.8.61-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting anyio<5.0,>=3.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading anyio-4.5.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting ffmpy (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.3.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting markupsafe~=2.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting matplotlib~=3.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Collecting orjson~=3.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading orjson-3.10.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting pandas<3.0,>=1.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting pillow<11.0,>=8.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pydantic>=2.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting pydub (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.2.2 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading ruff-0.9.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Collecting urllib3~=2.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting uvicorn>=0.14.0 (from gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading uvicorn-0.33.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading websockets-12.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting scikit-learn (from sentence_transformers>=2.4.0->-r requirements.txt (line 10))
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy (from sentence_transformers>=2.4.0->-r requirements.txt (line 10))
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Requirement already satisfied: psutil in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from accelerate>=0.29.2->-r requirements.txt (line 11)) (6.0.0)
# Collecting altair<6,>=4.0 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyarrow>=7.0 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading pyarrow-17.0.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting rich<14,>=10.14.0 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from streamlit>=1.33.0->-r requirements.txt (line 12)) (6.4.1)
# Collecting watchdog<7,>=2.1.5 (from streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl.metadata (38 kB)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi>=0.110.0->-r requirements.txt (line 13))
#   Downloading starlette-0.44.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from jupyter_client>=8.6.1->-r requirements.txt (line 17)) (8.5.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from jupyter_client>=8.6.1->-r requirements.txt (line 17)) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from jupyter_client>=8.6.1->-r requirements.txt (line 17)) (2.9.0)
# Requirement already satisfied: pyzmq>=23.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from jupyter_client>=8.6.1->-r requirements.txt (line 17)) (25.1.2)
# Requirement already satisfied: traitlets>=5.3 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from jupyter_client>=8.6.1->-r requirements.txt (line 17)) (5.14.3)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading narwhals-1.25.0-py3-none-any.whl.metadata (10 kB)
# Collecting idna>=2.8 (from anyio<5.0,>=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting sniffio>=1.1 (from anyio<5.0,>=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio<5.0,>=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting certifi (from httpx>=0.24.1->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: zipp>=3.20 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter_client>=8.6.1->-r requirements.txt (line 17)) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter_client>=8.6.1->-r requirements.txt (line 17)) (4.3.6)
# Collecting contourpy>=1.0.1 (from matplotlib~=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib~=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib~=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading fonttools-4.55.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib~=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib~=3.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Collecting pytz>=2020.1 (from pandas<3.0,>=1.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas<3.0,>=1.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=2.0->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading pydantic_core-2.27.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.5 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter_client>=8.6.1->-r requirements.txt (line 17)) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests->transformers>=4.39.3->-r requirements.txt (line 4))
#   Downloading charset_normalizer-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit>=1.33.0->-r requirements.txt (line 12)) (2.18.0)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio>=4.26.0->-r requirements.txt (line 8))
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting joblib>=1.1.1 (from scikit-learn->sentence_transformers>=2.4.0->-r requirements.txt (line 10))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence_transformers>=2.4.0->-r requirements.txt (line 10))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=2.1.0->-r requirements.txt (line 7))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading rpds_py-0.20.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.33.0->-r requirements.txt (line 12))
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading mdtex2html-1.3.0-py3-none-any.whl (13 kB)
# Downloading latex2mathml-3.75.0-py3-none-any.whl (72 kB)
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Using cached transformers-4.46.3-py3-none-any.whl (10.0 MB)
# Downloading tokenizers-0.20.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 17.9 MB/s eta 0:00:00
# Downloading cpm_kernels-1.0.11-py3-none-any.whl (416 kB)
# Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 16.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 17.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 27.6 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 30.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 10.4 MB/s eta 0:00:00
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 19.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 22.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 21.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 14.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 17.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 20.1 MB/s eta 0:00:0000:0100:01
# Downloading gradio-4.44.1-py3-none-any.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 12.3 MB/s eta 0:00:0000:0100:01
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading sentencepiece-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.2 MB/s eta 0:00:00
# Downloading sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
# Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 19.2 MB/s eta 0:00:00a 0:00:01
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 8.8 MB/s eta 0:00:00
# Downloading anyio-4.5.2-py3-none-any.whl (89 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachetools-5.5.1-py3-none-any.whl (9.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Downloading huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
# Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 18.9 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 19.8 MB/s eta 0:00:0000:0100:01
# Downloading orjson-3.10.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 19.7 MB/s eta 0:00:0000:010:01
# Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 14.9 MB/s eta 0:00:00a 0:00:01
# Downloading pyarrow-17.0.0-cp38-cp38-manylinux_2_28_x86_64.whl (40.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 20.9 MB/s eta 0:00:0000:0100:01
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 15.6 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 18.7 MB/s eta 0:00:00a 0:00:01
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (746 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 10.9 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (785 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 785.1/785.1 kB 11.0 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading ruff-0.9.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 20.1 MB/s eta 0:00:0000:0100:01
# Downloading safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.44.0-py3-none-any.whl (73 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typer-0.15.1-py3-none-any.whl (44 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading uvicorn-0.33.0-py3-none-any.whl (62 kB)
# Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl (82 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.6 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 21.0 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 18.9 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 17.0 MB/s eta 0:00:00a 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading fonttools-4.55.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 17.1 MB/s eta 0:00:00a 0:00:01
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.1 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading narwhals-1.25.0-py3-none-any.whl (313 kB)
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading websockets-12.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Downloading nvidia_nvjitlink_cu12-12.8.61-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.2/39.2 MB 1.2 MB/s eta 0:00:0000:010:00:03
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.20.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (360 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: sentencepiece, pytz, pydub, mpmath, cpm_kernels, websockets, watchdog, urllib3, tzdata, tqdm, tomlkit, toml, threadpoolctl, tenacity, sympy, sniffio, smmap, shellingham, semantic-version, safetensors, ruff, rpds-py, regex, pyyaml, python-multipart, pyparsing, pydantic-core, protobuf, pkgutil-resolve-name, pillow, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, narwhals, mdurl, markupsafe, loguru, latex2mathml, kiwisolver, joblib, importlib-resources, idna, h11, fsspec, fonttools, filelock, ffmpy, exceptiongroup, cycler, click, charset-normalizer, certifi, cachetools, blinker, attrs, annotated-types, aiofiles, uvicorn, triton, scipy, requests, referencing, pydantic, pyarrow, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, markdown-it-py, markdown, jinja2, httpcore, gitdb, contourpy, anyio, starlette, scikit-learn, rich, pydeck, nvidia-cusolver-cu12, mdtex2html, matplotlib, jsonschema-specifications, huggingface-hub, httpx, gitpython, typer, torch, tokenizers, jsonschema, gradio-client, fastapi, transformers, gradio, altair, accelerate, streamlit, sentence_transformers
# Successfully installed accelerate-1.0.1 aiofiles-23.2.1 altair-5.4.1 annotated-types-0.7.0 anyio-4.5.2 attrs-25.1.0 blinker-1.8.2 cachetools-5.5.1 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 contourpy-1.1.1 cpm_kernels-1.0.11 cycler-0.12.1 exceptiongroup-1.2.2 fastapi-0.115.8 ffmpy-0.5.0 filelock-3.16.1 fonttools-4.55.8 fsspec-2025.2.0 gitdb-4.0.12 gitpython-3.1.44 gradio-4.44.1 gradio-client-1.3.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 huggingface-hub-0.28.1 idna-3.10 importlib-resources-6.4.5 jinja2-3.1.5 joblib-1.4.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 kiwisolver-1.4.7 latex2mathml-3.75.0 loguru-0.7.3 markdown-3.7 markdown-it-py-3.0.0 markupsafe-2.1.5 matplotlib-3.7.5 mdtex2html-1.3.0 mdurl-0.1.2 mpmath-1.3.0 narwhals-1.25.0 networkx-3.1 numpy-1.24.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.8.61 nvidia-nvtx-cu12-12.1.105 orjson-3.10.15 pandas-2.0.3 pillow-10.4.0 pkgutil-resolve-name-1.3.10 protobuf-5.29.3 pyarrow-17.0.0 pydantic-2.10.6 pydantic-core-2.27.2 pydeck-0.9.1 pydub-0.25.1 pyparsing-3.1.4 python-multipart-0.0.20 pytz-2025.1 pyyaml-6.0.2 referencing-0.35.1 regex-2024.11.6 requests-2.32.3 rich-13.9.4 rpds-py-0.20.1 ruff-0.9.4 safetensors-0.5.2 scikit-learn-1.3.2 scipy-1.10.1 semantic-version-2.10.0 sentence_transformers-3.2.1 sentencepiece-0.2.0 shellingham-1.5.4 smmap-5.0.2 sniffio-1.3.1 starlette-0.44.0 streamlit-1.40.1 sympy-1.13.3 tenacity-9.0.0 threadpoolctl-3.5.0 tokenizers-0.20.3 toml-0.10.2 tomlkit-0.12.0 torch-2.4.1 tqdm-4.67.1 transformers-4.46.3 triton-3.0.0 typer-0.15.1 tzdata-2025.1 urllib3-2.2.3 uvicorn-0.33.0 watchdog-4.0.2 websockets-12.0

# %%
# %pip install bitsandbytes accelerate
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.1-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: accelerate in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: torch~=2.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from bitsandbytes) (2.4.1)
# Requirement already satisfied: numpy>=1.17 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from bitsandbytes) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: pyyaml in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from accelerate) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from accelerate) (0.5.2)
# Requirement already satisfied: filelock in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2025.2.0)
# Requirement already satisfied: requests in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (3.1)
# Requirement already satisfied: jinja2 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from torch~=2.0->bitsandbytes) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch~=2.0->bitsandbytes) (12.8.61)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from jinja2->torch~=2.0->bitsandbytes) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hoang/.conda/envs/my_env/lib/python3.8/site-packages (from sympy->torch~=2.0->bitsandbytes) (1.3.0)
# Downloading bitsandbytes-0.45.1-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 22.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%bash
# cd /home/hoang/EmpathyEar/chatglm
# source ./scripts/finetune_lora2.sh
# Out:
# ++ CUDA_VISIBLE_DEVICES=0
# ++ export NCCL_P2P_DISABLE=1
# ++ NCCL_P2P_DISABLE=1
# ++ export NCCL_IB_DISABLE=1
# ++ NCCL_IB_DISABLE=1
# ++ LR=1e-4
# ++ NUM_GPUS=1
# ++ LORA_RANK=8
# ++ LORA_ALPHA=16
# ++ LORA_DROUPOUT=0.1
# ++ MAX_SOURCE_LEN=1024
# ++ MAX_TARGET_LEN=512
# ++ DEV_BATCH_SIZE=1
# ++ GRAD_ACCUMULARION_STEPS=4
# ++ NUM_TRAIN_EPOCHS=4
# ++ SAVE_INTERVAL=24000
# ++ MAX_SEQ_LEN=1024
# ++ RUN_NAME=EED_4epoch
# ++ BASE_MODEL_PATH=THUDM/chatglm3-6b
# ++ DATASET_PATH=../Data/EED/EED4LLM_6000.json
# +++ date +%Y%m%d-%H%M%S
# ++ DATESTR=20250206-075200
# ++ OUTPUT_DIR=output/EED_4epoch-20250206-075200-1e-4
# +++ shuf -n 1 -i 10000-65535
# ++ MASTER_PORT=41511
# ++ mkdir -p output/EED_4epoch-20250206-075200-1e-4
# ++ python finetune2.py --train_format input-output --train_file ../Data/EED/EED4LLM_6000.json --lora_rank 8 --lora_alpha 16 --lora_dropout 0.1 --max_seq_length 1024 --preprocessing_num_workers 1 --model_name_or_path THUDM/chatglm3-6b --output_dir output/EED_4epoch-20250206-075200-1e-4 --per_device_train_batch_size 1 --gradient_accumulation_steps 4 --num_train_epochs 4 --logging_steps 1 --save_steps 24000 --learning_rate 1e-4
# ++ tee output/EED_4epoch-20250206-075200-1e-4/train.log
# 02/06/2025 07:52:06 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 2, distributed training: True, 16-bits training: True
# 02/06/2025 07:52:06 - INFO - __main__ - Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=2,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=False,
# batch_eval_metrics=False,
# bf16=True,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=False,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=None,
# eval_strategy=no,
# eval_use_gather_object=False,
# evaluation_strategy=None,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# generation_config=None,
# generation_max_length=None,
# generation_num_beams=None,
# gradient_accumulation_steps=4,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=0.0001,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=output/EED_4epoch-20250206-075200-1e-4/runs/Feb06_07-52-06_vjtechnologies,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=1.0,
# logging_strategy=steps,
# lr_scheduler_kwargs={},
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=4.0,
# optim=adamw_torch,
# optim_args=None,
# optim_target_modules=None,
# output_dir=output/EED_4epoch-20250206-075200-1e-4,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=1,
# predict_with_generate=False,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=[],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=output/EED_4epoch-20250206-075200-1e-4,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=24000,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# sortish_sampler=False,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_liger_kernel=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# [INFO|tokenization_utils_base.py:2211] 2025-02-06 07:52:09,360 >> loading file tokenizer.model from cache at /home/hoang/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/e9e0406d062cdb887444fe5bd546833920abd4ac/tokenizer.model
# [INFO|tokenization_utils_base.py:2211] 2025-02-06 07:52:09,361 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2211] 2025-02-06 07:52:09,361 >> loading file special_tokens_map.json from cache at /home/hoang/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/e9e0406d062cdb887444fe5bd546833920abd4ac/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2211] 2025-02-06 07:52:09,361 >> loading file tokenizer_config.json from cache at /home/hoang/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/e9e0406d062cdb887444fe5bd546833920abd4ac/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2211] 2025-02-06 07:52:09,361 >> loading file tokenizer.json from cache at None
# 02/06/2025 07:52:09 - WARNING - transformers_modules.THUDM.chatglm3-6b.e9e0406d062cdb887444fe5bd546833920abd4ac.tokenization_chatglm - Setting eos_token is not supported, use the default one.
# 02/06/2025 07:52:09 - WARNING - transformers_modules.THUDM.chatglm3-6b.e9e0406d062cdb887444fe5bd546833920abd4ac.tokenization_chatglm - Setting pad_token is not supported, use the default one.
# 02/06/2025 07:52:09 - WARNING - transformers_modules.THUDM.chatglm3-6b.e9e0406d062cdb887444fe5bd546833920abd4ac.tokenization_chatglm - Setting unk_token is not supported, use the default one.
# [INFO|configuration_utils.py:679] 2025-02-06 07:52:10,343 >> loading configuration file config.json from cache at /home/hoang/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/e9e0406d062cdb887444fe5bd546833920abd4ac/config.json
# [INFO|configuration_utils.py:679] 2025-02-06 07:52:10,639 >> loading configuration file config.json from cache at /home/hoang/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/e9e0406d062cdb887444fe5bd546833920abd4ac/config.json
# [INFO|configuration_utils.py:746] 2025-02-06 07:52:10,642 >> Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.46.3",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# [INFO|modeling_utils.py:3937] 2025-02-06 07:52:11,602 >> loading weights file model.safetensors from cache at /home/hoang/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/e9e0406d062cdb887444fe5bd546833920abd4ac/model.safetensors.index.json
# [INFO|modeling_utils.py:4034] 2025-02-06 07:52:11,605 >> Will use torch_dtype=torch.float16 as defined in model's config object
# [INFO|modeling_utils.py:1670] 2025-02-06 07:52:11,605 >> Instantiating ChatGLMForConditionalGeneration model under default dtype torch.float16.
# [INFO|configuration_utils.py:1096] 2025-02-06 07:52:11,608 >> Generate config GenerationConfig {
#   "eos_token_id": 2,
#   "pad_token_id": 0
# }
#
# [INFO|quantizer_bnb_4bit.py:122] 2025-02-06 07:52:14,707 >> target_dtype {target_dtype} is replaced by `CustomDtype.INT4` for 4-bit BnB quantization
# Loading checkpoint shards: 100%|██████████| 7/7 [00:07<00:00,  1.02s/it]
# [INFO|modeling_utils.py:4800] 2025-02-06 07:52:22,317 >> All model checkpoint weights were used when initializing ChatGLMForConditionalGeneration.
#
# [INFO|modeling_utils.py:4808] 2025-02-06 07:52:22,318 >> All the weights of ChatGLMForConditionalGeneration were initialized from the model checkpoint at THUDM/chatglm3-6b.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ChatGLMForConditionalGeneration for predictions without further training.
# [INFO|modeling_utils.py:4272] 2025-02-06 07:52:22,603 >> Generation config file not found, using a generation config created from the model config.
# 02/06/2025 07:52:22 - WARNING - accelerate.big_modeling - We've detected an older driver with an RTX 4000 series GPU. These drivers have issues with P2P. This can affect the multi-gpu inference when using accelerate device_map.Please make sure to update your driver to the latest version which resolves this.
# Train dataset size: 6000
# Sanity Check >>>>>>>>>>>>>
#            '[gMASK]':  64790 ->   -100
#                'sop':  64792 ->   -100
#                'You':    809 ->   -100
#                'are':    383 ->   -100
#                 'an':    284 ->   -100
#        'experienced':   4982 ->   -100
#                'and':    293 ->   -100
#                'emp':   5716 ->   -100
#            'athetic':  19089 ->   -100
#               'chat':   8911 ->   -100
#                'bot':  11879 ->   -100
#                  '.':  30930 ->   -100
#             'Unlike':  11909 ->   -100
#            'regular':   3011 ->   -100
#               'chat':   8911 ->   -100
#            'systems':   2727 ->   -100
#                  ',':  30932 ->   -100
#                'you':    344 ->   -100
#                'are':    383 ->   -100
#                  'a':    260 ->   -100
#            'virtual':   6689 ->   -100
#            'digital':   3821 ->   -100
#             'entity':   9613 ->   -100
#               'that':    343 ->   -100
#               'adap':  11155 ->   -100
#                 'ts':    933 ->   -100
#                'its':    667 ->   -100
#             'gender':   7542 ->   -100
#                  ',':  30932 ->   -100
#                'age':   2340 ->   -100
#                  ',':  30932 ->   -100
#                'and':    293 ->   -100
#              'voice':   3908 ->   -100
#                 'to':    289 ->   -100
#             'better':   1374 ->   -100
#              'serve':   4188 ->   -100
#          'different':   1134 ->   -100
#              'users':   3386 ->   -100
#                  '.':  30930 ->   -100
#                'Now':   2179 ->   -100
#                'you':    344 ->   -100
#                'are':    383 ->   -100
#           'provided':   2556 ->   -100
#               'with':    356 ->   -100
#                  'a':    260 ->   -100
#       'conversation':   6088 ->   -100
#              'which':    559 ->   -100
#           'contains':   5035 ->   -100
#               'user':   2795 ->   -100
#                  "'":  30953 ->   -100
#                  's':  30917 ->   -100
#            'current':   1465 ->   -100
#            'queries':  18202 ->   -100
#                'and':    293 ->   -100
#       'conversation':   6088 ->   -100
#            'history':   1993 ->   -100
#                  '.':  30930 ->   -100
#               'Your':  14545 ->   -100
#               'task':   4778 ->   -100
#                 'is':    323 ->   -100
#              'first':    726 ->   -100
#                 'ly':    329 ->   -100
#                 'to':    289 ->   -100
#         'comprehend':  27240 ->   -100
#                'the':    267 ->   -100
#           'provided':   2556 ->   -100
#       'conversation':   6088 ->   -100
#        'information':   1097 ->   -100
#                 'to':    289 ->   -100
#                'the':    267 ->   -100
#               'best':   1077 ->   -100
#                 'of':    290 ->   -100
#               'your':    475 ->   -100
#            'ability':   3264 ->   -100
#                  ',':  30932 ->   -100
#                'and':    293 ->   -100
#               'then':    832 ->   -100
#                 'to':    289 ->   -100
#            'proceed':   5280 ->   -100
#               'with':    356 ->   -100
#                  'a':    260 ->   -100
#               'step':   2155 ->   -100
#                  '-':  30941 ->   -100
#                 'by':   1556 ->   -100
#                  '-':  30941 ->   -100
#               'step':  10176 ->   -100
#                  ',':  30932 ->   -100
#                 'in':    291 ->   -100
#                  '-':  30941 ->   -100
#              'depth':  13637 ->   -100
#           'analysis':   3356 ->   -100
#          'following':   1762 ->   -100
#                'the':    267 ->   -100
#          'procedure':   6847 ->   -100
#           'outlined':  17238 ->   -100
#              'below':   2426 ->   -100
#                  ',':  30932 ->   -100
#                'and':    293 ->   -100
#            'finally':   3745 ->   -100
#             'output':   4836 ->   -100
#               'your':    475 ->   -100
#            'results':   2136 ->   -100
#                 'of':    290 ->   -100
#               'each':   1108 ->   -100
#               'step':   2155 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '1':  30939 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#                 'Em':  10582 ->   -100
#              'otion':  10200 ->   -100
#              'Cause':  25763 ->   -100
#                  '>':  30994 ->   -100
#                'The':    353 ->   -100
#             'reason':   1920 ->   -100
#             'behind':   2615 ->   -100
#                'the':    267 ->   -100
#               'user':   2795 ->   -100
#                  "'":  30953 ->   -100
#                  's':  30917 ->   -100
#          'emotional':   6780 ->   -100
#              'state':   1353 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '2':  30943 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#              'Event':   7278 ->   -100
#                 'Sc':   1152 ->   -100
#                 'en':    272 ->   -100
#               'ario':   4794 ->   -100
#                  '>':  30994 ->   -100
#                'The':    353 ->   -100
#           'scenario':  10169 ->   -100
#                 'in':    291 ->   -100
#              'which':    559 ->   -100
#                'the':    267 ->   -100
#       'conversation':   6088 ->   -100
#              'takes':   2791 ->   -100
#              'place':   1234 ->   -100
#                  '.':  30930 ->   -100
#                'You':    809 ->   -100
#                'can':    457 ->   -100
#              'focus':   1923 ->   -100
#                 'on':    331 ->   -100
#                'the':    267 ->   -100
#             'events':   2617 ->   -100
#          'mentioned':   4777 ->   -100
#                 'in':    291 ->   -100
#                'the':    267 ->   -100
#       'conversation':   6088 ->   -100
#                 'or':    400 ->   -100
#                'inf':   1183 ->   -100
#                 'er':    266 ->   -100
#                'the':    267 ->   -100
#           'scenario':  10169 ->   -100
#              'based':   1767 ->   -100
#                 'on':    331 ->   -100
#             'common':   2229 ->   -100
#              'sense':   2661 ->   -100
#                'and':    293 ->   -100
#             'domain':   6845 ->   -100
#          'knowledge':   2841 ->   -100
#                  ',':  30932 ->   -100
#               'such':    866 ->   -100
#                 'as':    362 ->   -100
#              'daily':   3991 ->   -100
#       'conversation':   6088 ->   -100
#                  ',':  30932 ->   -100
#      'psychological':  12217 ->   -100
#         'assistance':   6167 ->   -100
#                  ',':  30932 ->   -100
#              'elder':  10771 ->   -100
#             'people':    705 ->   -100
#            'company':   1441 ->   -100
#                  ',':  30932 ->   -100
#                 'or':    400 ->   -100
#           'children':   1559 ->   -100
#            'company':   1441 ->   -100
#                  ',':  30932 ->   -100
#                'etc':   2859 ->   -100
#                  '.':  30930 ->   -100
#                'The':    353 ->   -100
#             'result':   1169 ->   -100
#                 'of':    290 ->   -100
#               'this':    434 ->   -100
#               'step':   2155 ->   -100
#                 'is':    323 ->   -100
#            'summary':  10035 ->   -100
#                  '-':  30941 ->   -100
#           'oriented':  16338 ->   -100
#                  ',':  30932 ->   -100
#            'ideally':  27027 ->   -100
#         'consisting':  14456 ->   -100
#                 'of':    290 ->   -100
#                 'no':    687 ->   -100
#               'more':    548 ->   -100
#               'than':    664 ->   -100
#                   '':  30910 ->   -100
#                  '5':  30970 ->   -100
#              'words':   2499 ->   -100
#                'and':    293 ->   -100
#           'allowing':   6074 ->   -100
#                'for':    332 ->   -100
#         'repetition':  29971 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '3':  30966 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#                  'R':  30951 ->   -100
#            'ational':    770 ->   -100
#                  'e':  30911 ->   -100
#                  '>':  30994 ->   -100
#                'The':    353 ->   -100
#         'underlying':  10419 ->   -100
#            'reasons':   4139 ->   -100
#             'behind':   2615 ->   -100
#                'the':    267 ->   -100
#               'user':   2795 ->   -100
#                  "'":  30953 ->   -100
#                  's':  30917 ->   -100
#           'emotions':  10146 ->   -100
#                 'or':    400 ->   -100
#                'the':    267 ->   -100
#         'occurrence':  20000 ->   -100
#                 'of':    290 ->   -100
#                'the':    267 ->   -100
#            'current':   1465 ->   -100
#              'event':   1685 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '4':  30972 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#                 'Go':   7450 ->   -100
#                 'al':    285 ->   -100
#                 'to':    289 ->   -100
#           'Response':  13656 ->   -100
#                  '>':  30994 ->   -100
#             'Determ':  20125 ->   -100
#                'ine':    478 ->   -100
#                'the':    267 ->   -100
#               'goal':   3300 ->   -100
#                'the':    267 ->   -100
#               'chat':   8911 ->   -100
#                'bot':  11879 ->   -100
#             'should':    865 ->   -100
#                'aim':   3840 ->   -100
#                'for':    332 ->   -100
#                 'in':    291 ->   -100
#                'its':    667 ->   -100
#           'response':   3010 ->   -100
#              'based':   1767 ->   -100
#                 'on':    331 ->   -100
#                'the':    267 ->   -100
#           'analysis':   3356 ->   -100
#               'from':    428 ->   -100
#                'the':    267 ->   -100
#           'previous':   2461 ->   -100
#              'steps':   4726 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '5':  30970 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#              'Agent':  29322 ->   -100
#             'gender':   7542 ->   -100
#                  '>':  30994 ->   -100
#                'The':    353 ->   -100
#             'gender':   7542 ->   -100
#                 'of':    290 ->   -100
#                'the':    267 ->   -100
#               'chat':   8911 ->   -100
#                'bot':  11879 ->   -100
#                  ',':  30932 ->   -100
#          'selecting':  15357 ->   -100
#               'from':    428 ->   -100
#               'male':   5960 ->   -100
#                'and':    293 ->   -100
#             'female':   5397 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '6':  30978 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#              'Agent':  29322 ->   -100
#                'age':   2340 ->   -100
#                  '>':  30994 ->   -100
#                'The':    353 ->   -100
#                'age':   2340 ->   -100
#                 'of':    290 ->   -100
#                'the':    267 ->   -100
#               'chat':   8911 ->   -100
#                'bot':  11879 ->   -100
#                  ',':  30932 ->   -100
#          'selecting':  15357 ->   -100
#               'from':    428 ->   -100
#           'Children':   5987 ->   -100
#                  ',':  30932 ->   -100
#               'Teen':  18532 ->   -100
#              'agers':  10758 ->   -100
#                  ',':  30932 ->   -100
#              'Young':   6160 ->   -100
#             'Adults':  27119 ->   -100
#                  ',':  30932 ->   -100
#             'Middle':   5908 ->   -100
#                  '-':  30941 ->   -100
#               'aged':   2452 ->   -100
#             'Adults':  27119 ->   -100
#                'and':    293 ->   -100
#              'Elder':  22333 ->   -100
#                 'ly':    329 ->   -100
#             'Adults':  27119 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '7':  30981 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#              'Agent':  29322 ->   -100
#                'Tim':   4980 ->   -100
#                'bre':   3738 ->   -100
#                'and':    293 ->   -100
#                  'T':    304 ->   -100
#                'one':    521 ->   -100
#                  '>':  30994 ->   -100
#                'The':    353 ->   -100
#                'tim':   4053 ->   -100
#                'bre':   3738 ->   -100
#                 'of':    290 ->   -100
#                'the':    267 ->   -100
#               'chat':   8911 ->   -100
#                'bot':  11879 ->   -100
#                  ',':  30932 ->   -100
#          'selecting':  15357 ->   -100
#               'from':    428 ->   -100
#                'Low':   8679 ->   -100
#                  '-':  30941 ->   -100
#                  'p':  30925 ->   -100
#             'itched':  13095 ->   -100
#                  ',':  30932 ->   -100
#               'Soft':   7757 ->   -100
#                  ',':  30932 ->   -100
#              'Clear':  11098 ->   -100
#                  ',':  30932 ->   -100
#                'Mel':   5054 ->   -100
#                 'od':    374 ->   -100
#               'ious':    719 ->   -100
#                  ',':  30932 ->   -100
#               'warm':   4160 ->   -100
#                  ',':  30932 ->   -100
#                'hus':   4163 ->   -100
#                 'ky':   4659 ->   -100
#                  ',':  30932 ->   -100
#             'bright':   5954 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '8':  30973 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#                  'E':  30950 ->   -100
#                 'mp':   3274 ->   -100
#            'athetic':  19089 ->   -100
#           'Response':  13656 ->   -100
#                  '>':  30994 ->   -100
#                 'Le':   1008 ->   -100
#                'ver':    341 ->   -100
#              'aging':   2740 ->   -100
#                'the':    267 ->   -100
#      'comprehensive':   7130 ->   -100
#           'analysis':   3356 ->   -100
#                 'of':    290 ->   -100
#                'the':    267 ->   -100
#     'aforementioned':  22892 ->   -100
#              'steps':   4726 ->   -100
#                  ',':  30932 ->   -100
#            'provide':   1628 ->   -100
#                'the':    267 ->   -100
#               'user':   2795 ->   -100
#               'with':    356 ->   -100
#                 'an':    284 ->   -100
#                'emp':   5716 ->   -100
#            'athetic':  19089 ->   -100
#           'response':   3010 ->   -100
#                 'to':    289 ->   -100
#              'their':    537 ->   -100
#              'query':   9065 ->   -100
#                  '.':  30930 ->   -100
#               'Step':  20533 ->   -100
#                   '':  30910 ->   -100
#                  '9':  30969 ->   -100
#                  ':':  30954 ->   -100
#                  '<':    906 ->   -100
#                 'Em':  10582 ->   -100
#            'otional':  19575 ->   -100
#           'Response':  13656 ->   -100
#                  '>':  30994 ->   -100
#                'The':    353 ->   -100
#          'emotional':   6780 ->   -100
#               'tone':   9461 ->   -100
#             'convey':  12706 ->   -100
#                 'ed':    286 ->   -100
#               'when':    650 ->   -100
#                'rep':   1100 ->   -100
#              'lying':   3085 ->   -100
#                 'to':    289 ->   -100
#                'the':    267 ->   -100
#               'user':   2795 ->   -100
#                  '.':  30930 ->   -100
#               'Here':  17029 ->   -100
#                 'is':    323 ->   -100
#                 'an':    284 ->   -100
#            'example':   1822 ->   -100
#                  ',':  30932 ->   -100
#              'given':   1845 ->   -100
#                'the':    267 ->   -100
#              'input':   4432 ->   -100
#                  ':':  30954 ->   -100
#                 "{'":  25914 ->   -100
#               'User':   7750 ->   -100
#              'Query':  29955 ->   -100
#                 "':":   5440 ->   -100
#                  '"':    449 ->   -100
#                 'It':   2053 ->   -100
#                  "'":  30953 ->   -100
#                  's':  30917 ->   -100
#                'all':    479 ->   -100
#            'because':    881 ->   -100
#                 'of':    290 ->   -100
#                'the':    267 ->   -100
#            'traffic':   5261 ->   -100
#                'jam':  17437 ->   -100
#                  '.':  30930 ->   -100
#                 'It':    577 ->   -100
#                'was':    401 ->   -100
#           'terrible':   9829 ->   -100
#                'and':    293 ->   -100
#               'very':    844 ->   -100
#        'frustrating':  17880 ->   -100
#                '.",':  23490 ->   -100
#                  "'":    765 ->   -100
#                'Con':   2669 ->   -100
#               'vers':    663 ->   -100
#              'ation':    340 ->   -100
#            'History':   4477 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#                  '[':  30995 ->   -100
#               'User':   7750 ->   -100
#                  ']':  30996 ->   -100
#                  'I':  30936 ->   -100
#                'was':    401 ->   -100
#               'late':   2835 ->   -100
#                'for':    332 ->   -100
#               'work':    636 ->   -100
#              'today':   1661 ->   -100
#                 '.[':   4218 ->   -100
#              'Agent':  29322 ->   -100
#                  ']':  30996 ->   -100
#                'Can':   9791 ->   -100
#                'you':    344 ->   -100
#               'tell':   1719 ->   -100
#                 'me':    496 ->   -100
#               'what':    658 ->   -100
#           'happened':   3983 ->   -100
#                 "?'":  10596 ->   -100
#                 '}.':  19784 ->   -100
#               'Your':   2260 ->   -100
#             'output':   4836 ->   -100
#               'must':   1296 ->   -100
#           'strictly':  14594 ->   -100
#             'comply':  12313 ->   -100
#               'with':    356 ->   -100
#                'the':    267 ->   -100
#               'JSON':  17560 ->   -100
#             'format':   5588 ->   -100
#                'and':    293 ->   -100
#            'refrain':  29964 ->   -100
#               'from':    428 ->   -100
#             'output':   4836 ->   -100
#               'ting':    875 ->   -100
#                'any':    612 ->   -100
#              'other':    593 ->   -100
#         'irrelevant':  21006 ->   -100
#            'content':   2384 ->   -100
#                  ',':  30932 ->   -100
#                 'as':    362 ->   -100
#              'shown':   3542 ->   -100
#                 'in':    291 ->   -100
#                'the':    267 ->   -100
#          'following':   1762 ->   -100
#             'output':   4836 ->   -100
#            'example':   1822 ->   -100
#                  ':':  30954 ->   -100
#                 "{'":  25914 ->   -100
#                 'Em':  10582 ->   -100
#              'otion':  10200 ->   -100
#              'Cause':  25763 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#                'Tra':  16454 ->   -100
#               'ffic':   2013 ->   -100
#                'jam':  17437 ->   -100
#                  '.':  30930 ->   -100
#                 "',":   1589 ->   -100
#                  "'":    765 ->   -100
#              'Event':   7278 ->   -100
#                 'Sc':   1152 ->   -100
#                 'en':    272 ->   -100
#               'ario':   4794 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#               'Work':  13623 ->   -100
#                  '-':  30941 ->   -100
#            'related':   5747 ->   -100
#             'stress':   4685 ->   -100
#                  '.':  30930 ->   -100
#                 "',":   1589 ->   -100
#                  "'":    765 ->   -100
#                  'R':  30951 ->   -100
#            'ational':    770 ->   -100
#                  'e':  30911 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#                'Tra':  16454 ->   -100
#               'ffic':   2013 ->   -100
#                'jam':  17437 ->   -100
#            'results':   2136 ->   -100
#                 'in':    291 ->   -100
#                'lat':   2520 ->   -100
#              'eness':   9940 ->   -100
#                  ',':  30932 ->   -100
#            'causing':   8486 ->   -100
#        'individuals':   3861 ->   -100
#                 'to':    289 ->   -100
#               'feel':   1322 ->   -100
#            'anxious':  17904 ->   -100
#                'and':    293 ->   -100
#         'frustrated':  17458 ->   -100
#                  '.':  30930 ->   -100
#                 "',":   1589 ->   -100
#                  "'":    765 ->   -100
#                 'Go':   7450 ->   -100
#                 'al':    285 ->   -100
#                 'to':    289 ->   -100
#           'Response':  13656 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#                 'Al':   4649 ->   -100
#                'lev':   1909 ->   -100
#             'iating':  24279 ->   -100
#            'anxiety':   9566 ->   -100
#                'and':    293 ->   -100
#                 'ag':    619 ->   -100
#            'itation':   3129 ->   -100
#                  '.':  30930 ->   -100
#                 "',":   1589 ->   -100
#                  "'":    765 ->   -100
#              'Agent':  29322 ->   -100
#             'Gender':  20460 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#                  'F':  30960 ->   -100
#                 'em':    372 ->   -100
#                'ale':   1003 ->   -100
#                 "',":   1589 ->   -100
#                  "'":    765 ->   -100
#              'Agent':  29322 ->   -100
#                'Age':   8692 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#                  'Y':  30986 ->   -100
#               'oung':   5569 ->   -100
#             'adults':   6180 ->   -100
#                 "',":   1589 ->   -100
#                  "'":    765 ->   -100
#              'Agent':  29322 ->   -100
#                'Tim':   4980 ->   -100
#                'bre':   3738 ->   -100
#                'and':    293 ->   -100
#                  'T':    304 ->   -100
#                'one':    521 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#               'Soft':  28870 ->   -100
#                 "',":   1589 ->   -100
#                  "'":    765 ->   -100
#                  'E':  30950 ->   -100
#                 'mp':   3274 ->   -100
#            'athetic':  19089 ->   -100
#                'Rep':   1565 ->   -100
#               'onse':   2248 ->   -100
#                 "':":   5440 ->   -100
#                  '"':    449 ->   -100
#                  'I':  30936 ->   -100
#                'can':    457 ->   -100
#            'imagine':   6397 ->   -100
#                'how':    709 ->   -100
#        'frustrating':  17880 ->   -100
#                'and':    293 ->   -100
#        'challenging':   7890 ->   -100
#                 'it':    354 ->   -100
#               'must':   1296 ->   -100
#               'have':    431 ->   -100
#               'been':    628 ->   -100
#                 'to':    289 ->   -100
#               'deal':   2002 ->   -100
#               'with':    356 ->   -100
#               'such':    866 ->   -100
#                  'a':    260 ->   -100
#           'terrible':   9829 ->   -100
#            'traffic':   5261 ->   -100
#                'jam':  17437 ->   -100
#                  '.':  30930 ->   -100
#                 'It':    577 ->   -100
#                  "'":  30953 ->   -100
#                  's':  30917 ->   -100
#     'understandable':  24824 ->   -100
#               'that':    343 ->   -100
#                 'it':    354 ->   -100
#             'caused':   4907 ->   -100
#                'you':    344 ->   -100
#                 'to':    289 ->   -100
#                 'be':    330 ->   -100
#               'late':   2835 ->   -100
#                'for':    332 ->   -100
#               'work':    636 ->   -100
#                '.",':  23490 ->   -100
#                  "'":    765 ->   -100
#                 'Em':  10582 ->   -100
#            'otional':  19575 ->   -100
#           'Response':  13656 ->   -100
#                 "':":   5440 ->   -100
#                  "'":    765 ->   -100
#                  'T':  30935 ->   -100
#                'err':   1300 ->   -100
#              'ified':   1540 ->   -100
#                  "'":  30953 ->   -100
#                 '}.':  19784 ->   -100
#                   '':  30910 ->   -100
#                 '\n':     13 ->   -100
#                'Now':   2179 ->   -100
#               'here':    985 ->   -100
#                 'is':    323 ->   -100
#                  'a':    260 ->   -100
#              'input':   4432 ->   -100
#                'for':    332 ->   -100
#                'you':    344 ->   -100
#                  ':':  30954 ->   -100
#                 '\n':     13 ->   -100
#               'User':   8151 ->   -100
#              'Query':  29955 ->   -100
#                  ':':  30954 ->   -100
#                  'I':  30936 ->   -100
#           'remember':   3170 ->   -100
#              'going':   1132 ->   -100
#                 'to':    289 ->   -100
#                'see':    777 ->   -100
#                'the':    267 ->   -100
#          'fireworks':  26963 ->   -100
#               'with':    356 ->   -100
#                 'my':    552 ->   -100
#               'best':   1077 ->   -100
#             'friend':   1454 ->   -100
#                  '.':  30930 ->   -100
#                 'It':    577 ->   -100
#                'was':    401 ->   -100
#                'the':    267 ->   -100
#              'first':    726 ->   -100
#               'time':    622 ->   -100
#                 'we':    379 ->   -100
#               'ever':   1765 ->   -100
#              'spent':   3684 ->   -100
#               'time':    622 ->   -100
#              'alone':   3916 ->   -100
#           'together':   1811 ->   -100
#                  '.':  30930 ->   -100
#           'Although':   3802 ->   -100
#              'there':    627 ->   -100
#                'was':    401 ->   -100
#                  'a':    260 ->   -100
#                'lot':   1271 ->   -100
#                 'of':    290 ->   -100
#             'people':    705 ->   -100
#                  ',':  30932 ->   -100
#                 'we':    379 ->   -100
#               'felt':   3219 ->   -100
#               'like':    659 ->   -100
#                'the':    267 ->   -100
#               'only':    742 ->   -100
#             'people':    705 ->   -100
#                 'in':    291 ->   -100
#                'the':    267 ->   -100
#              'world':    993 ->   -100
#                  '.':  30930 ->   -100
#                   '':  30910 ->   -100
#                 '\n':     13 ->   -100
#       'Conversation':  29629 ->   -100
#            'History':   4477 ->   -100
#                  ':':  30954 ->   -100
#               'None':  10343 ->   -100
#                 '\n':     13 ->   -100
#                   '':  30910 ->   -100
#                  '"':    449 ->    449
#                 'Em':  10582 ->  10582
#              'otion':  10200 ->  10200
#              'Cause':  25763 ->  25763
#                 '":':   2932 ->   2932
#                  '"':    449 ->    449
#                'Rec':   9264 ->   9264
#             'alling':  13902 ->  13902
#               'time':    622 ->    622
#              'spent':   3684 ->   3684
#               'with':    356 ->    356
#                  'a':    260 ->    260
#               'best':   1077 ->   1077
#             'friend':   1454 ->   1454
#                 'at':    388 ->    388
#          'fireworks':  26963 ->  26963
#                '.",':  23490 ->  23490
#                  '"':    449 ->    449
#              'Event':   7278 ->   7278
#                 'Sc':   1152 ->   1152
#                 'en':    272 ->    272
#               'ario':   4794 ->   4794
#                 '":':   2932 ->   2932
#                  '"':    449 ->    449
#                 'Sh':   3962 ->   3962
#               'ared':   1253 ->   1253
#             'memory':   4554 ->   4554
#                '.",':  23490 ->  23490
#                  '"':    449 ->    449
#                  'R':  30951 ->  30951
#            'ational':    770 ->    770
#                  'e':  30911 ->  30911
#                 '":':   2932 ->   2932
#                  '"':    449 ->    449
#                'Ref':  11134 ->  11134
#               'lect':    749 ->    749
#                'ing':    283 ->    283
#                 'on':    331 ->    331
#                  'a':    260 ->    260
#            'special':   1720 ->   1720
#             'moment':   2698 ->   2698
#             'shared':   4831 ->   4831
#               'with':    356 ->    356
#                  'a':    260 ->    260
#               'best':   1077 ->   1077
#             'friend':   1454 ->   1454
#                  ',':  30932 ->  30932
#         'especially':   2462 ->   2462
#                'one':    544 ->    544
#             'marked':   8385 ->   8385
#                 'by':    422 ->    422
#                  'a':    260 ->    260
#        'significant':   2527 ->   2527
#              'first':    726 ->    726
#         'experience':   1524 ->   1524
#                'and':    293 ->    293
#          'emotional':   6780 ->   6780
#           'intimacy':  30529 ->  30529
#               'amid':  13648 ->  13648
#                  'a':    260 ->    260
#            'crowded':  18029 ->  18029
#            'setting':   4378 ->   4378
#                  ',':  30932 ->  30932
#              'often':   1712 ->   1712
#                 'ev':    605 ->    605
#               'okes':   6724 ->   6724
#               'sent':   2312 ->   2312
#            'imental':   7922 ->   7922
#           'feelings':   7841 ->   7841
#                '.",':  23490 ->  23490
#                  '"':    449 ->    449
#                 'Go':   7450 ->   7450
#                 'al':    285 ->    285
#                 'to':    289 ->    289
#           'Response':  13656 ->  13656
#                 '":':   2932 ->   2932
#                  '"':    449 ->    449
#                  'A':  30938 ->  30938
#                 'ff':    486 ->    486
#                'irm':   2285 ->   2285
#                'the':    267 ->    267
#           'positive':   3621 ->   3621
#             'memory':   4554 ->   4554
#                'and':    293 ->    293
#          'emotional':   6780 ->   6780
#       'significance':  11769 ->  11769
#                 'of':    290 ->    290
#                'the':    267 ->    267
#         'experience':   1524 ->   1524
#                '.",':  23490 ->  23490
#                  '"':    449 ->    449
#              'Agent':  29322 ->  29322
#             'Gender':  20460 ->  20460
#                 '":':   2932 ->   2932
#                  '"':    449 ->    449
#                  'F':  30960 ->  30960
#                 'em':    372 ->    372
#                'ale':   1003 ->   1003
#                 '",':   1252 ->   1252
#                  '"':    449 ->    449
#              'Agent':  29322 ->  29322
#                'Age':   8692 ->   8692
#                 '":':   2932 ->   2932
#                  '"':    449 ->    449
#                  'Y':  30986 ->  30986
#               'oung':   5569 ->   5569
#             'Adults':  27119 ->  27119
#                 '",':   1252 ->   1252
#                  '"':    449 ->    449
#              'Agent':  29322 ->  29322
#                'Tim':   4980 ->   4980
#                'bre':   3738 ->   3738
#                'and':    293 ->    293
#                  'T':    304 ->    304
#                'one':    521 ->    521
#                 '":':   2932 ->   2932
#                  '"':    449 ->    449
#                  'W':  30959 ->  30959
#                'arm':   1103 ->   1103
#                '","':  10906 ->  10906
#                  'E':  30950 ->  30950
#                 'mp':   3274 ->   3274
#            'athetic':  19089 ->  19089
#           'Response':  13656 ->  13656
#                 '":':   2932 ->   2932
#                  'W':  30959 ->  30959
#                 'as':    298 ->    298
#               'this':    434 ->    434
#                  'a':    260 ->    260
#             'friend':   1454 ->   1454
#                'you':    344 ->    344
#               'were':    614 ->    614
#                 'in':    291 ->    291
#               'love':   1379 ->   1379
#               'with':    356 ->    356
#                  ',':  30932 ->  30932
#                 'or':    400 ->    400
#               'just':    680 ->    680
#                  'a':    260 ->    260
#               'best':   1077 ->   1077
#             'friend':   1454 ->   1454
#                  '?':  30987 ->  30987
#                  '"':    449 ->    449
#                 'Em':  10582 ->  10582
#            'otional':  19575 ->  19575
#           'Response':  13656 ->  13656
#                 '":':   2932 ->   2932
#               'sent':  23723 ->  23723
#            'imental':   7922 ->   7922
#                  '"':  30955 ->  30955
#                   '':      2 ->      2
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
# ...
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
#                   '':      0 ->   -100
# <<<<<<<<<<<<< Sanity Check
# /home/hoang/EmpathyEar/chatglm/trainer.py:33: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `LoRATrainer.__init__`. Use `processing_class` instead.
#   super().__init__(*args, **kwargs)
# 02/06/2025 07:52:23 - WARNING - accelerate.utils.other - Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# [INFO|trainer.py:483] 2025-02-06 07:52:23,593 >> You have loaded a model on multiple GPUs. `is_model_parallel` attribute will be force-set to `True` to avoid any unexpected behavior such as device placement mismatching.
# [INFO|trainer.py:699] 2025-02-06 07:52:24,401 >> Using auto half precision backend
# [INFO|trainer.py:2314] 2025-02-06 07:52:24,769 >> ***** Running training *****
# [INFO|trainer.py:2315] 2025-02-06 07:52:24,769 >>   Num examples = 6,000
# [INFO|trainer.py:2316] 2025-02-06 07:52:24,769 >>   Num Epochs = 4
# [INFO|trainer.py:2317] 2025-02-06 07:52:24,769 >>   Instantaneous batch size per device = 1
# [INFO|trainer.py:2320] 2025-02-06 07:52:24,769 >>   Total train batch size (w. parallel, distributed & accumulation) = 4
# [INFO|trainer.py:2321] 2025-02-06 07:52:24,769 >>   Gradient Accumulation steps = 4
# [INFO|trainer.py:2322] 2025-02-06 07:52:24,769 >>   Total optimization steps = 6,000
# [INFO|trainer.py:2323] 2025-02-06 07:52:24,773 >>   Number of trainable parameters = 1,949,696
#   0%|          | 0/6000 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "finetune2.py", line 208, in <module>
#     main()
#   File "finetune2.py", line 202, in main
#     trainer.train()
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/transformers/trainer.py", line 2123, in train
#     return inner_training_loop(
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/transformers/trainer.py", line 2481, in _inner_training_loop
#     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/transformers/trainer.py", line 3579, in training_step
#     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#   File "/home/hoang/EmpathyEar/chatglm/trainer.py", line 36, in compute_loss
#     return model(**inputs).loss
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/peft/peft_model.py", line 1644, in forward
#     return self.base_model(
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/peft/tuners/tuners_utils.py", line 197, in forward
#     return self.model.forward(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/accelerate/hooks.py", line 170, in new_forward
#     output = module._old_forward(*args, **kwargs)
#   File "/home/hoang/.cache/huggingface/modules/transformers_modules/THUDM/chatglm3-6b/e9e0406d062cdb887444fe5bd546833920abd4ac/modeling_chatglm.py", line 955, in forward
#     transformer_outputs = self.transformer(
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/hoang/.cache/huggingface/modules/transformers_modules/THUDM/chatglm3-6b/e9e0406d062cdb887444fe5bd546833920abd4ac/modeling_chatglm.py", line 838, in forward
#     hidden_states, presents, all_hidden_states, all_self_attentions = self.encoder(
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/hoang/.cache/huggingface/modules/transformers_modules/THUDM/chatglm3-6b/e9e0406d062cdb887444fe5bd546833920abd4ac/modeling_chatglm.py", line 645, in forward
#     layer_ret = layer(
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/accelerate/hooks.py", line 170, in new_forward
#     output = module._old_forward(*args, **kwargs)
#   File "/home/hoang/.cache/huggingface/modules/transformers_modules/THUDM/chatglm3-6b/e9e0406d062cdb887444fe5bd546833920abd4ac/modeling_chatglm.py", line 569, in forward
#     mlp_output = self.mlp(layernorm_output)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/accelerate/hooks.py", line 170, in new_forward
#     output = module._old_forward(*args, **kwargs)
#   File "/home/hoang/.cache/huggingface/modules/transformers_modules/THUDM/chatglm3-6b/e9e0406d062cdb887444fe5bd546833920abd4ac/modeling_chatglm.py", line 502, in forward
#     intermediate_parallel = self.dense_h_to_4h(hidden_states)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/accelerate/hooks.py", line 170, in new_forward
#     output = module._old_forward(*args, **kwargs)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/bitsandbytes/nn/modules.py", line 484, in forward
#     return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/bitsandbytes/autograd/_functions.py", line 533, in matmul_4bit
#     return MatMul4Bit.apply(A, B, out, bias, quant_state)
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/torch/autograd/function.py", line 574, in apply
#     return super().apply(*args, **kwargs)  # type: ignore[misc]
#   File "/home/hoang/.conda/envs/my_env/lib/python3.8/site-packages/bitsandbytes/autograd/_functions.py", line 462, in forward
#     output = torch.nn.functional.linear(A, F.dequantize_4bit(B, quant_state).to(A.dtype).t(), bias)
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 214.00 MiB. GPU 1 has a total capacity of 23.65 GiB of which 55.31 MiB is free. Process 227983 has 12.46 GiB memory in use. Process 1388980 has 2.58 GiB memory in use. Including non-PyTorch memory, this process has 8.54 GiB memory in use. Of the allocated memory 7.61 GiB is allocated by PyTorch, and 481.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#   0%|          | 0/6000 [00:03<?, ?it/s]
