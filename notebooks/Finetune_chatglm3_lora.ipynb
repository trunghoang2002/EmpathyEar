# %%
# !python -V
# Out:
# Python 3.8.20

# %%
import torch
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 12.1
# True

# %% [markdown]
# **Check the readme.md in the chatglm folder for setup before run the finetuning**

# %%
# %%bash
# cd /home/hoang/EmpathyEar/chatglm
# source ./scripts/finetune_lora2.sh
# Out:
# ++ CUDA_VISIBLE_DEVICES=0
# ++ export NCCL_P2P_DISABLE=1
# ++ NCCL_P2P_DISABLE=1
# ++ export NCCL_IB_DISABLE=1
# ++ NCCL_IB_DISABLE=1
# ++ LR=1e-4
# ++ NUM_GPUS=1
# ++ LORA_RANK=8
# ++ LORA_ALPHA=16
# ++ LORA_DROUPOUT=0.1
# ++ MAX_SOURCE_LEN=1024
# ++ MAX_TARGET_LEN=512
# ++ DEV_BATCH_SIZE=1
# ++ GRAD_ACCUMULARION_STEPS=4
# ++ NUM_TRAIN_EPOCHS=4
# ++ SAVE_INTERVAL=24000
# ++ MAX_SEQ_LEN=1024
# ++ RUN_NAME=EED_4epoch
# ++ BASE_MODEL_PATH=THUDM/chatglm3-6b
# ++ DATASET_PATH=../Data/EED/EED4LLM_6000.json
# +++ date +%Y%m%d-%H%M%S
# ++ DATESTR=20250206-075200
# ++ OUTPUT_DIR=output/EED_4epoch-20250206-075200-1e-4
# +++ shuf -n 1 -i 10000-65535
# ++ MASTER_PORT=41511
# ++ mkdir -p output/EED_4epoch-20250206-075200-1e-4
# ...
